# %% [markdown]
# # Colormaps for images and label images
# This notebook is just for reproducing some figures from our slides. It demonstrates how different libraries can be used for image visualization.

# %%
import matplotlib.pyplot as plt
import stackview
from skimage import io

# %%
# Load the image
image = io.imread('data/blobs.tif')
labels = io.imread('data/blobs_labels.tif')

# %%
plt.imshow(image)

# %%
io.imshow(image)
# Out:
# C:\Users\rober\AppData\Local\Temp\ipykernel_46732\2038164919.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(image)

# %%
stackview.imshow(image)

# %%
plt.imshow(labels)

# %%
io.imshow(labels)
# Out:
# C:\Users\rober\AppData\Local\Temp\ipykernel_46732\28416559.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(labels)
# C:\Users\rober\miniforge3\envs\bob-env\Lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:158: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
stackview.imshow(labels)
