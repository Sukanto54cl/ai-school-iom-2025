# %% [markdown]
# # Installation @ jupyter4nfdi
# This notebook is supposed to be executed on [https://hub.nfdi-jupyter.de/](https://hub.nfdi-jupyter.de/). Before running it, make sure open a terminal and execute `unzip env.zip` within this folder. Do NOT unzip it from within a notebook because you need to enter a password.

# %%
# !pip install bia-bob openai dotenv pandas scikit-image numpy scipy stackview statsmodels seaborn plotly scikit-learn
# Out:
# ...
#   Using cached bia_bob-0.34.3-py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached openai-2.2.0-py3-none-any.whl.metadata (29 kB)
# ...
#   Using cached dotenv-0.9.9-py2.py3-none-any.whl.metadata (279 bytes)
# ...
#   Using cached scikit_image-0.25.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# ...
#   Using cached scipy-1.16.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (62 kB)
# ...
#   Using cached stackview-0.18.0-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached scikit_learn-1.7.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# ...
#   Using cached pillow-11.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.0 kB)
# ...
#   Using cached networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached tifffile-2025.10.4-py3-none-any.whl.metadata (30 kB)
# ...
