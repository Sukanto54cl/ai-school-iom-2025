# %%
import pandas as pd

housing_data = pd.read_csv('housing_data.csv')
print(f"Following data was read (showing only first 5 rows):\n{housing_data.head()}")
# Out:
# Following data was read (showing only first 5 rows):
#    MedInc  HouseAge  Latitude  Longitude  price
# 0  8.3252      41.0     37.88    -122.23  4.526
# 1  8.3014      21.0     37.86    -122.22  3.585
# 2  7.2574      52.0     37.85    -122.24  3.521
# 3  5.6431      52.0     37.85    -122.25  3.413
# 4  3.8462      52.0     37.85    -122.25  3.422

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(housing_data, test_size=0.2, random_state=42)

# %%
corr_matrix = train_set.corr()
print(corr_matrix["price"])
# Out:
# MedInc       0.650230
# HouseAge     0.068858
# Latitude    -0.147477
# Longitude   -0.048017
# price        1.000000
# Name: price, dtype: float64

# %%
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt

attributes = ["MedInc", "HouseAge", "Latitude", "Longitude", "price"]
scatter_matrix(train_set[attributes], figsize=(12, 8))
plt.show()
